# %%
# 1+2+3+4+5...+98+99+100
# for
# suma=1+2+3+4...+99+100

# %%
for i in range(10):
  print("El valor de i es",i)
# Out:
# El valor de i es 0
# El valor de i es 1
# El valor de i es 2
# El valor de i es 3
# El valor de i es 4
# El valor de i es 5
# El valor de i es 6
# El valor de i es 7
# El valor de i es 8
# El valor de i es 9

# %%
for j in range(5):
  print("El valor de i es", j)
# Out:
# El valor de i es 0
# El valor de i es 1
# El valor de i es 2
# El valor de i es 3
# El valor de i es 4

# %%
#100+102+102+...+199+200=?
suma=0
for i in range(100,201):
  suma=suma+(i)
  #print(i+1)
print(suma)
# suma=0,  i=0,i+1=1
# Out:
# 15150

# %%
for i in range(5,10):
  print(i)
# Out:
# 5
# 6
# 7
# 8
# 9

# %%
for i in range(10,16):
  print(i)
# Out:
# 10
# 11
# 12
# 13
# 14
# 15

# %%
for i in range(1,21,5):
  print(i)
# Out:
# 1
# 6
# 11
# 16

# %%
# Un programa donde le piden al usuario el limite superior
# para realizar la suma partiendo desde cero y hasta llegar
# al limite superior
# si el usuario me dice que el limite superior es 145
# suma de 1+2+3+4+...+145

# %%
limite=int(input('Escribe el limite superior: '))
suma=0
for i in range(1,limite+1):
  suma+=i #suma=suma+i
print(suma)
# Out:
# Escribe el limite superior: 10
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-5615cfe9ebfd> in <module>
# ----> 1 limite=int(input('Escribe el limite superior: '))
#       2 suma=0
#       3 for i in range(1,limite+1):
#       4   suma+=i #suma=suma+i
#       5 print(suma)
#
# TypeError: 'str' object is not callable

# %%
9/4
# Out:
# 2.25

# %%
9//4
# Out:
# 2

# %%
9%4 #modulo
# 4+4=8
# 4+4+4=12
# Out:
# 1

# %%
9%5
# 5+5=10
# 9//5 > 1
# Out:
# 4

# %%
print('Este programa suma numeros pares')
print('En un rango desde 1 hasta el que nos diga')
print('el usuario.')
#2+4+6+8+10+...+par del limite superior
limite=int(input('Escribe el limite superior: '))
suma=0
for i in range(1,limite+1):
  if i%2==0:
    suma+=i #suma=suma+i
print(suma)
# sumar unicamente numeros primos
# Out:
# Este programa suma numeros pares
# En un rango desde 1 hasta el que nos diga
# el usuario.
# Escribe el limite superior: 30
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-85794b8add84> in <module>
#       3 print('el usuario.')
#       4 #2+4+6+8+10+...+par del limite superior
# ----> 5 limite=int(input('Escribe el limite superior: '))
#       6 suma=0
#       7 for i in range(1,limite+1):
#
# TypeError: 'str' object is not callable
